# %% [markdown]
# # Линейная регрессия на PyTorch

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# %matplotlib inline

# %%
num_inputs = 2 # количество признаков (входов)
num_examples = 1000 # количество значений
true_w = torch.tensor([2, -3.4]) # истинные значения весов
true_b = 4.2 # Истинное значение смещения
features = torch.randn((num_examples, num_inputs)) # Генерируем набор значений
labels = torch.mv(features, true_w) + true_b # Рассчитываем метки
labels += torch.randn(labels.shape) # Добавляем к меткам случайный шум

# %% [markdown]
# ## Dataset - это экземпляр класса TensorDataset

# %%
dataset = TensorDataset(features, labels)
print(dataset.tensors[0])
print(dataset.tensors[1])
# Out:
# tensor([[ 1.6169, -0.2811],
#         [ 0.1068, -1.7612],
#         [-0.5749,  1.4517],
#         ...,
#         [ 1.0706,  1.2314],
#         [-0.5934, -0.9372],
#         [ 0.7511, -0.4628]])
# tensor([ 7.3603e+00,  1.1383e+01, -1.2258e+00,  2.9441e-01,  9.7091e+00,
#          3.4931e+00,  7.8927e+00, -5.8346e-01,  4.0616e+00,  5.7830e+00,
#          7.8042e+00,  5.4642e+00,  8.8773e+00,  8.1266e+00,  4.3782e+00,
#          3.6732e+00,  5.8331e+00,  2.6155e+00,  7.3060e+00,  3.8338e+00,
#          1.9800e+00,  4.9357e+00,  2.5621e+00,  1.3893e+01,  2.2097e+00,
#         -1.4028e+00,  1.1808e+01,  1.6647e+00,  4.8142e+00,  8.2210e-01,
#          7.7418e+00, -1.2186e+00,  2.4585e-01,  3.6602e+00, -3.5242e-01,
#          2.5200e+00,  9.6757e+00,  2.8899e+00, -2.3405e+00,  8.8528e+00,
#          6.9093e+00,  7.3208e+00,  2.7313e+00,  7.8064e+00,  4.9583e-01,
#          6.0899e+00,  9.5722e+00,  6.5317e+00,  7.2023e+00,  7.7666e+00,
#         -5.7642e-01, -3.1204e-01, -2.1728e+00,  2.1046e+00,  5.2765e+00,
#          3.0909e+00,  2.4814e-02,  2.7364e+00,  7.7030e+00,  8.0360e+00,
#          3.2353e+00,  2.8761e-01,  8.8240e+00,  9.9565e+00,  8.7967e+00,
#         -1.4764e+00,  7.5233e-01,  7.9573e+00,  4.8232e-02,  9.9125e+00,
#          2.1043e+00,  7.5985e-01,  1.0505e+01,  2.9911e+00,  1.8811e+00,
#          1.4212e+00,  3.4076e+00,  6.6977e+00,  9.3794e+00,  8.9928e+00,
#         -3.0446e+00,  2.2671e+00,  8.4425e+00,  2.4864e+00,  5.7623e+00,
#         -3.4867e+00,  2.7579e+00,  9.8269e+00,  9.6417e+00, -4.2693e+00,
#          9.3233e+00,  3.6200e+00,  4.2457e+00,  2.7181e+00,  4.7159e+00,
#          3.0613e+00,  5.0203e+00,  6.1342e+00,  1.6728e+00,  8.9603e+00,
#          6.0142e+00,  3.8104e-01,  7.4404e+00,  1.5267e+00,  3.8064e+00,
#          1.9704e+00,  3.0094e+00,  8.9610e+00,  5.4928e+00,  5.6799e+00,
#          1.9389e+00,  1.1034e+01, -5.0523e-01, -1.5635e+00, -1.8394e-01,
#          2.9339e+00,  3.5495e+00,  6.1002e+00,  3.3378e+00,  2.3762e+00,
#          5.4774e+00,  1.1570e+00, -2.1579e+00,  5.3436e+00,  5.2876e+00,
#          3.1232e+00,  1.2561e+00,  9.2598e+00,  5.1404e+00,  4.4153e+00,
#          4.1468e+00,  1.0415e+01,  3.4526e+00,  6.0670e+00, -4.0299e+00,
#          1.0158e+01,  4.3893e+00,  2.5710e+00,  4.3454e+00,  7.5336e+00,
#          1.5175e+00,  1.0932e+01,  2.0706e-01,  2.1063e+00,  1.0636e+01,
#          9.1289e-01,  8.3558e+00,  6.2648e+00,  5.3242e+00,  3.1540e+00,
#         -9.5762e-01,  9.8916e+00,  2.3440e+00,  2.0523e+00,  4.7162e-01,
#          3.4065e+00,  9.0630e-01,  4.6251e+00,  1.2319e+01,  3.7604e+00,
#          9.7070e-01,  1.9455e+00,  8.8699e+00,  7.8176e+00,  1.0037e+01,
#          3.9267e+00,  3.2452e+00,  3.8783e+00,  5.4634e+00,  4.5703e+00,
#          6.3686e+00,  5.9134e+00,  2.5292e+00,  4.4570e+00,  9.4751e+00,
#         -2.9465e+00,  4.1456e+00,  4.0047e+00,  3.5377e+00, -1.5547e+00,
#          3.7752e-01,  2.7396e+00,  3.7533e+00, -4.1399e+00,  5.1915e+00,
#          1.0489e+01,  1.0509e+01,  6.0066e+00,  6.3044e+00,  5.9876e+00,
#          8.3532e+00,  6.5371e+00,  4.8457e+00, -1.3448e+00,  1.4009e-01,
#          7.9724e-01,  7.8556e+00,  1.0266e+00, -5.0568e-01,  4.5425e+00,
#          1.0329e+01,  2.1950e+00, -2.6473e-02,  5.2850e+00,  8.6497e+00,
#          3.6423e+00,  5.7872e+00,  5.5084e+00,  5.6806e+00,  4.0165e+00,
#          1.1041e+00,  2.2426e+00,  1.6426e+01,  1.5496e+00,  1.2121e+01,
#          4.9274e+00, -2.2174e+00,  5.4491e+00,  2.3635e-01, -1.0465e+00,
#          4.4854e+00,  7.8149e+00,  7.1950e+00,  6.4999e+00,  2.9730e+00,
#          2.6516e+00,  4.1712e+00,  7.0856e+00, -1.6195e+00,  6.9977e+00,
#          1.2147e+00,  1.2494e+01, -2.2295e+00,  9.4056e+00,  6.7535e+00,
#          8.6506e+00,  5.1744e+00,  5.6236e+00,  1.4252e+01,  7.0928e+00,
#          3.4015e+00,  6.7543e+00,  8.0145e+00,  5.3428e+00,  8.6359e-01,
#         -2.8444e+00,  7.7234e+00,  1.1636e+01,  4.9404e+00,  2.2038e+00,
#         -1.0711e-01,  9.5975e+00,  1.5760e+01,  4.7727e+00,  9.9879e+00,
#          8.3153e+00,  1.0524e+00,  4.6745e+00,  3.9155e-01,  1.1371e+00,
#         -1.0590e+00,  2.1865e+00,  8.0581e+00,  4.7411e+00,  6.8176e+00,
#          1.9508e+00,  3.5445e+00,  4.5211e+00,  8.2124e-01,  6.4856e+00,
#          6.5044e+00,  3.7723e+00,  7.4992e+00, -1.0880e+01,  8.8958e+00,
#          2.1415e+00,  3.6838e+00,  1.6354e+00,  1.0392e+00,  1.0850e+01,
#          4.1518e+00,  8.5831e+00,  8.4291e+00,  9.4722e+00,  3.0568e+00,
#          9.1084e+00,  4.5212e-01, -1.9129e+00,  5.4506e+00,  3.3581e+00,
#          3.7011e+00,  4.8976e-01,  4.8254e+00,  9.4040e+00,  5.3329e+00,
#          1.0972e+01,  6.1920e+00,  1.3545e+00, -3.5166e+00,  3.8812e+00,
#          1.7925e+00,  1.1201e+01,  2.9804e+00,  2.6496e+00,  3.5206e+00,
#          7.0517e-01,  5.0606e-01,  6.6265e+00,  4.5891e+00,  3.4179e+00,
#          1.1552e+01,  2.4223e-01,  7.4542e+00,  7.9537e+00,  3.1765e+00,
#          9.1672e+00, -2.2424e+00,  4.3682e+00,  2.3499e+00,  4.9281e+00,
#          4.0253e+00, -2.1255e+00,  2.4722e+00,  1.2115e+00,  1.0292e+00,
#          7.0782e+00,  6.9874e-01,  6.4353e+00,  9.0232e+00,  7.0688e+00,
#          7.8610e+00, -3.4582e+00,  4.1360e+00,  4.1883e+00,  2.0581e+00,
#          6.2916e+00, -3.0734e-01,  3.5399e+00,  5.5284e+00,  9.2555e+00,
#          2.3905e+00, -1.0428e+00,  8.8595e+00,  6.6669e+00, -3.7768e-01,
#          8.0319e+00,  6.4426e+00,  7.5123e+00,  6.4524e+00,  5.5226e+00,
#          1.1328e+01,  8.3805e+00,  2.1231e+00,  5.1708e+00,  1.3325e+00,
#          6.7558e+00,  2.9153e+00,  5.4790e+00,  6.5835e+00, -3.5929e+00,
#          3.6555e+00,  5.4153e+00,  2.9505e+00, -1.9058e-01,  2.4666e+00,
#          3.4598e+00, -2.9213e+00,  5.3211e+00,  1.0286e+01,  7.7493e+00,
#          2.0406e+00, -1.7816e+00,  1.2458e+00,  4.7019e+00,  6.3564e+00,
#          1.2330e+00,  5.1968e+00,  7.8797e+00,  7.2674e+00,  6.7010e+00,
#         -1.6984e+00,  1.0326e+01,  1.0829e+01, -1.3304e+00,  1.6839e+00,
#          5.9021e+00, -1.3592e+00,  6.2769e+00,  1.1431e-01,  7.7899e+00,
#          3.7376e+00,  1.1565e+01,  2.7152e+00,  1.0767e+01, -3.4021e-01,
#         -3.0918e+00,  5.2615e-01,  6.3210e+00,  3.5281e+00,  4.2353e+00,
#          4.8504e+00,  4.1682e+00, -2.0605e+00,  2.2069e+00,  8.3600e-01,
#          6.8437e+00,  1.2058e-01,  1.1057e+01, -4.8231e+00,  1.0370e+00,
#          6.4205e+00,  4.0740e+00,  4.3414e+00, -3.4188e+00,  4.0629e+00,
#          4.8430e-01,  9.1929e+00,  4.3417e+00,  1.2706e+00,  4.1342e+00,
#          1.9701e+00,  5.0543e+00,  5.8805e+00,  4.1101e+00,  3.5126e+00,
#          1.6675e+00, -2.3838e+00,  3.1203e+00,  1.0269e+01,  7.2290e+00,
#          7.6556e+00, -1.9439e+00,  1.0325e+01,  4.8173e+00,  1.2525e+00,
#          1.0143e+00,  4.6683e+00,  5.4000e+00, -8.0796e-01,  2.4412e+00,
#          4.7016e+00,  8.9644e+00,  3.2147e-01,  3.5747e+00,  6.6770e+00,
#          1.0041e+01,  4.6804e+00,  2.3962e+00,  9.0651e+00,  5.2019e+00,
#          6.4824e+00,  4.9267e+00,  6.5853e+00, -5.6617e-02,  3.2616e+00,
#          5.7515e+00,  1.0319e+00,  2.3119e+00,  1.6841e+00,  1.2364e+01,
#          3.2091e+00,  4.5252e+00, -2.9384e-01,  6.0939e+00,  7.6017e+00,
#          5.3029e+00,  1.3357e+01,  7.7553e+00,  7.9160e+00,  4.6769e+00,
#          1.1403e+01,  2.9652e+00,  4.8407e+00,  1.9351e+00,  2.1539e+00,
#          8.0020e+00,  1.0712e+01, -8.4618e-01,  8.8801e+00,  2.5199e-02,
#          9.0690e+00,  2.2001e+00,  5.8877e+00,  1.8565e+00,  4.9482e+00,
#          2.3947e+00,  1.0082e+01, -8.8898e-01, -1.4219e-01,  5.8609e+00,
#         -4.6677e+00,  6.1381e+00,  2.7956e+00,  9.0162e-01,  8.0994e+00,
#          9.2011e+00,  3.6374e+00,  4.2990e+00,  1.5788e+00,  4.3402e+00,
#          3.2050e+00,  6.6260e+00, -6.1014e-01, -6.7147e+00,  9.0464e-01,
#          5.4954e+00, -4.1897e-01,  2.4603e+00,  4.1078e+00,  4.5952e+00,
#          5.3458e+00,  1.3241e+01,  7.9420e+00,  5.3893e+00,  1.0477e+01,
#          8.4095e+00, -3.5647e+00,  8.1135e+00, -3.5496e+00,  5.6142e+00,
#          3.6475e+00,  2.7246e+00,  9.1791e+00,  4.3551e+00,  3.8262e-01,
#          5.1182e+00,  5.9079e+00,  1.9592e+00,  1.6342e+00,  6.5165e+00,
#         -7.8863e-01,  5.9302e+00,  7.5379e+00,  1.6293e+00,  5.9274e+00,
#         -3.0466e-01,  4.2351e+00,  4.8509e+00,  2.8854e+00,  1.7633e+00,
#          8.6812e+00,  2.5615e+00,  1.1492e+01,  1.6332e+00,  1.2436e+00,
#          6.0766e-01,  1.1537e+01,  3.2013e+00, -2.2471e+00,  3.6376e+00,
#          3.8975e+00,  3.5124e+00, -4.3791e+00,  7.9100e+00,  3.9657e-01,
#          7.9515e+00,  4.6950e+00,  4.9678e+00, -4.6736e+00,  5.3545e+00,
#          7.7516e+00,  4.2374e+00, -1.6794e+00,  3.2377e+00,  8.5036e+00,
#          3.3107e+00,  7.3437e+00,  4.5957e+00,  5.1667e+00,  5.5513e+00,
#          6.9376e+00,  5.2424e-02,  1.2788e+00,  6.9099e+00,  4.5475e+00,
#          3.9431e+00,  4.0556e+00,  9.0932e+00,  5.7720e+00,  1.0208e+01,
#          5.4349e+00,  1.0948e+01,  1.0800e+01,  6.4562e+00,  3.5260e+00,
#          1.3058e+01,  5.8498e+00,  6.4062e+00,  4.6787e+00,  6.8763e+00,
#          1.7777e-01,  2.7613e+00,  6.1143e+00,  3.1840e+00,  7.4159e+00,
#          7.4645e+00,  6.4938e+00,  7.3170e+00,  5.2186e+00, -6.2684e+00,
#          3.7855e+00,  9.8119e+00,  1.0140e+01,  7.3999e+00,  8.3547e+00,
#          4.3548e+00, -6.2587e-01,  5.8165e+00,  2.7921e+00,  9.3005e+00,
#          1.7697e-02,  1.2087e+01,  3.3425e+00,  5.5512e+00,  7.7532e-01,
#          1.0154e+01,  1.1710e+00,  5.2498e+00,  7.8859e+00,  7.3058e-01,
#          4.0170e+00,  2.2304e+00,  7.2837e+00,  2.5315e-01,  4.0901e+00,
#          9.2509e+00,  8.5808e+00,  1.1042e+00,  8.4701e+00,  6.3133e+00,
#         -1.9267e+00,  1.3504e+01,  1.9839e+00,  4.5811e+00,  4.0768e+00,
#          1.0508e+01,  7.2404e-01,  7.8972e+00,  6.5628e+00,  5.7411e+00,
#          9.7507e+00,  9.3272e+00,  1.0008e+01,  8.3393e+00,  1.5270e-01,
#          5.2211e+00,  6.2339e+00,  6.3639e+00,  7.5594e+00,  1.1268e+01,
#          6.5651e+00,  7.4704e+00,  4.6447e+00,  4.5973e+00, -2.2873e+00,
#         -3.1333e+00,  6.6352e+00,  9.7617e+00,  1.3726e+00,  8.9527e+00,
#          9.1722e+00,  6.3093e+00,  6.8489e+00,  5.1386e+00, -9.6469e-01,
#          5.2013e+00,  8.7509e+00,  3.5268e+00,  9.3780e+00,  2.3902e+00,
#          3.4566e+00,  8.6886e+00,  6.5656e+00,  6.2351e+00,  4.2210e+00,
#          6.7775e+00,  3.2481e+00,  5.8926e+00,  8.0365e+00, -1.5496e+00,
#          5.4417e+00,  8.1836e+00,  2.2310e+00,  5.2675e+00,  1.2096e+01,
#         -2.5800e-01,  9.9862e+00, -1.5398e+00,  6.2372e+00,  2.9541e+00,
#          5.0149e-01,  1.6586e+01,  9.8532e+00,  5.7891e+00, -2.3900e+00,
#          7.5556e+00,  1.9256e+00,  3.2493e+00,  8.0274e+00,  3.0414e+00,
#          5.5325e+00,  8.8315e+00,  3.2563e+00,  4.4952e-01,  5.1883e+00,
#          8.7010e+00,  1.7150e+00,  4.0162e-01, -3.1565e+00,  1.0210e+01,
#          8.4319e+00,  8.8767e+00,  1.2921e+01,  1.2519e+00,  1.3606e+00,
#          3.6461e+00,  5.1802e+00,  2.2868e+00,  1.6844e+01, -8.1073e-01,
#          7.1380e+00,  8.6296e+00,  6.4800e+00,  7.5416e+00,  5.3581e+00,
#         -2.7665e+00,  2.3586e+00,  6.7916e+00,  5.5045e+00, -4.5479e+00,
#          1.1904e+00,  9.8776e+00,  7.9210e+00,  7.1260e+00,  8.1091e+00,
#          1.7892e-01,  4.0635e+00,  2.1187e+00, -5.7857e-01,  2.1943e+00,
#         -2.7292e+00,  8.5656e+00,  1.3787e+00,  6.6207e+00, -3.6283e+00,
#          6.7263e+00,  6.9286e+00,  4.0596e+00,  4.7440e+00,  7.3115e+00,
#          5.4609e+00,  4.7614e+00,  9.7138e+00,  5.8223e+00,  9.8624e-01,
#          6.9351e+00, -1.8991e+00,  1.5878e+00,  5.3828e+00,  7.4791e+00,
#          2.9229e+00,  7.0127e+00,  7.8379e+00,  6.0803e+00,  5.8920e+00,
#          2.7628e+00,  3.1710e+00,  1.0827e+01, -1.2075e+00,  1.0360e+01,
#          6.6785e+00,  4.0039e+00, -3.3210e+00,  5.4041e+00,  1.0105e+01,
#          5.3059e+00,  4.3132e+00,  3.4862e+00,  2.2010e+00, -2.9341e-01,
#          3.4431e+00,  5.2406e+00, -4.5426e+00,  2.3561e+00,  5.2251e+00,
#          7.2971e+00,  4.2169e+00,  3.4007e+00,  2.8373e+00,  1.0838e+01,
#          2.3444e-02,  7.2568e+00,  1.2296e+00, -4.2590e+00,  9.9991e+00,
#          3.1228e+00,  9.3196e+00,  5.5114e+00,  1.0446e+01,  9.0119e+00,
#          3.8244e+00,  8.3934e+00,  8.3073e-01,  7.3706e+00,  4.7040e+00,
#          9.1816e-01,  6.4445e+00,  3.6721e+00,  1.4098e+00, -1.2555e-01,
#          3.5502e+00,  7.2335e+00,  3.6373e+00,  3.0298e+00,  6.9337e+00,
#         -6.7784e-01,  5.3437e+00,  3.5625e+00,  4.2992e+00,  6.2293e+00,
#          7.3769e+00,  7.4832e+00,  1.1275e+00,  1.2910e+01,  1.3570e+00,
#          6.7803e+00,  2.7710e+00,  1.1701e+01, -5.4366e-01,  9.1895e+00,
#          6.8318e+00,  3.1091e+00,  6.5272e-01, -1.4134e+00,  9.6818e+00,
#          5.6647e+00,  9.6712e+00, -8.4903e-01,  4.8406e+00,  8.7209e+00,
#          4.0321e+00,  3.9001e+00,  1.5081e+01,  2.1847e+00,  3.2790e+00,
#          2.4990e+00,  3.6971e+00,  4.4647e+00,  9.6162e+00,  6.1679e+00,
#          8.5992e+00,  9.7458e+00,  1.1747e+00,  1.6747e+00,  2.3325e+00,
#         -3.4378e+00,  7.9720e+00,  7.9881e+00,  2.9051e+00,  4.1098e+00,
#          3.1368e+00, -1.1412e+00, -3.0204e+00, -4.3741e+00,  6.6003e+00,
#          8.0215e+00,  8.8347e+00,  1.8026e+00,  6.6881e-03,  4.3010e+00,
#          6.3984e+00,  9.8087e-01,  2.8087e-01,  7.4061e+00, -2.2234e+00,
#          4.9993e+00,  9.0260e+00, -9.9526e-01,  8.6321e-01, -4.0135e-01,
#         -3.3384e+00,  8.4027e+00,  6.3202e+00,  1.3614e+00,  1.3905e+00,
#          2.8469e+00,  2.8329e+00,  3.4938e+00,  1.0252e+01,  1.2223e+01,
#          2.3314e+00, -2.4445e+00,  3.3698e+00,  6.4903e+00, -3.6689e+00,
#          2.7173e+00, -1.9563e+00,  1.0426e+00,  4.1714e+00,  1.9218e+00,
#         -2.1878e+00,  7.9031e+00,  5.5866e+00,  4.3809e+00, -2.0653e+00,
#          3.1207e+00, -2.9649e+00,  8.6189e+00,  6.0593e-01, -2.7063e+00,
#          1.3096e+01,  6.4292e+00,  4.5434e+00,  7.0089e+00,  1.3544e+00,
#          3.6513e-01,  8.5189e+00,  2.3562e+00, -4.1094e-01,  7.9186e+00,
#          7.6957e+00,  4.6804e+00,  4.8131e+00,  7.6587e+00,  1.1504e+01,
#          1.3147e+00,  6.5473e+00, -3.4567e+00,  2.7461e+00,  4.0493e+00,
#          2.5516e-01,  6.6976e+00,  8.6095e+00,  7.9242e+00,  7.5605e+00,
#          5.3902e+00,  4.0355e+00, -1.1251e+00,  4.2818e+00, -5.5284e-01,
#          8.1826e+00, -3.8706e+00,  2.0462e+00,  3.3247e+00,  1.0158e+01,
#          1.3891e+01,  8.8608e-01,  7.3631e+00, -3.4340e+00,  6.4824e+00,
#          5.3340e+00,  2.1673e+00, -6.0043e+00,  1.7145e+00,  5.7223e+00,
#          3.6196e+00, -1.3038e+00,  5.1885e+00,  6.0824e+00, -4.0337e+00,
#          1.8767e+00,  7.7038e+00,  6.1513e+00,  6.9943e+00,  4.4196e+00,
#          1.8851e+00,  5.7966e+00,  2.2520e-01, -1.0153e+00,  6.0710e+00,
#          2.5225e+00, -2.1171e+00,  4.4831e+00,  1.1183e+00,  7.4256e+00,
#         -7.5802e-01, -3.9714e+00,  1.0410e+01,  7.5543e+00, -6.1441e-02,
#          6.4511e+00,  3.4405e+00, -3.4287e+00,  4.1205e+00,  2.8729e-01,
#          7.0358e-02,  1.2281e+01, -9.9309e-01,  4.4354e+00,  1.2837e+00,
#          6.2687e+00,  2.6742e+00, -1.7692e-01, -3.3366e+00,  3.0209e+00,
#          8.2165e+00, -8.4151e-01,  4.0493e+00,  5.2070e+00,  8.8814e+00])

# %% [markdown]
# ## DataIterator - это экземпляр класса DataLoader

# %%
# Randomly reading mini-batches
batch_size = 10
data_iter = DataLoader(dataset, batch_size, shuffle=True)

# %% [markdown]
# ### Выведем один batch размером = 10

# %%
for X, y in data_iter:
    print(X, y)
    break
# Out:
# tensor([[-1.1564,  1.4867],
#         [ 1.4812,  2.5007],
#         [ 0.7936,  0.9376],
#         [ 0.9252, -0.8306],
#         [ 1.2141, -0.0881],
#         [ 0.5697,  0.4753],
#         [-0.8011,  0.6381],
#         [-0.4970, -1.0039],
#         [ 0.8167,  0.4431],
#         [-1.2180, -0.1619]]) tensor([-3.6283, -1.4134,  2.7628,  9.3272,  5.4634,  2.9505,  0.2876,  6.4353,
#          5.3029,  3.3107])

# %% [markdown]
# ## Строим модель

# %% [markdown]
# ### Задаем модель

# %%
# var_1 (Позволяет делать мнгослойные модели)
model_01 = torch.nn.Sequential(torch.nn.Linear(2, 1))
model_01
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=1, bias=True)
# )

# %%
# var_2 (Достаточен для нашего примера)
model_02 = torch.nn.Linear(2, 1)
model_02
# Out:
# Linear(in_features=2, out_features=1, bias=True)

# %% [markdown]
# ### Инициализируем веса модели

# %%
# # var_1
# model_01[0].weight.data = true_w.clone().detach().requires_grad_(True).reshape((1, 2))
# model_01[0].bias.data = torch.tensor([true_b], requires_grad=True)

# %%
# # var_2
# model_02.weight.data = true_w.clone().detach().requires_grad_(True).reshape((1, 2))
# model_02.bias.data = torch.tensor([true_b], requires_grad=True)

# %% [markdown]
# > По умолчанию Torch инициализирует начальные значения параметров по методу, признанному лучним на сегодняшний день

# %% [markdown]
# ### Функция потерь

# %%
loss = torch.nn.MSELoss(reduction='mean')

# %% [markdown]
# ### Создаем опримизатор

# %%
# var_1
trainer_01 = torch.optim.SGD(model_01.parameters(), lr=0.001)

# var_2
trainer_02 = torch.optim.SGD(model_02.parameters(), lr=0.001)

# %% [markdown]
# > Надо всегда следить за размерностями тензоров!

# %% [markdown]
# ### Обучение

# %%
num_epochs = 100
for epoch in range(1, num_epochs + 1):
    for X, y in data_iter:
        trainer_01.zero_grad()
        l = loss(model_01(X).reshape(-1), y)
        l.backward()
        trainer_01.step()
    l = loss(model_01(features).reshape(-1), labels)
    if epoch % 5 == 0:
        print('epoch %d, loss: %f' % (epoch, l.item()),
              '|\tw', model_01[0].weight.data,
              '|\tb', model_01[0].bias.data)
# Out:
# epoch 5, loss: 4.568942 |	w tensor([[ 1.3520, -2.3620]]) |	b tensor([2.7493])
# epoch 10, loss: 1.441925 |	w tensor([[ 1.7501, -3.0129]]) |	b tensor([3.6742])
# epoch 15, loss: 1.051614 |	w tensor([[ 1.8944, -3.2383]]) |	b tensor([4.0023])
# epoch 20, loss: 1.002722 |	w tensor([[ 1.9461, -3.3186]]) |	b tensor([4.1180])
# epoch 25, loss: 0.996641 |	w tensor([[ 1.9652, -3.3475]]) |	b tensor([4.1580])
# epoch 30, loss: 0.995881 |	w tensor([[ 1.9713, -3.3568]]) |	b tensor([4.1729])
# epoch 35, loss: 0.995788 |	w tensor([[ 1.9745, -3.3594]]) |	b tensor([4.1776])
# epoch 40, loss: 0.995772 |	w tensor([[ 1.9758, -3.3612]]) |	b tensor([4.1798])
# epoch 45, loss: 0.995774 |	w tensor([[ 1.9775, -3.3609]]) |	b tensor([4.1805])
# epoch 50, loss: 0.995772 |	w tensor([[ 1.9770, -3.3623]]) |	b tensor([4.1806])
# epoch 55, loss: 0.995770 |	w tensor([[ 1.9764, -3.3615]]) |	b tensor([4.1811])
# epoch 60, loss: 0.995770 |	w tensor([[ 1.9758, -3.3618]]) |	b tensor([4.1813])
# epoch 65, loss: 0.995770 |	w tensor([[ 1.9753, -3.3616]]) |	b tensor([4.1805])
# epoch 70, loss: 0.995772 |	w tensor([[ 1.9753, -3.3609]]) |	b tensor([4.1800])
# epoch 75, loss: 0.995770 |	w tensor([[ 1.9756, -3.3613]]) |	b tensor([4.1809])
# epoch 80, loss: 0.995770 |	w tensor([[ 1.9752, -3.3623]]) |	b tensor([4.1812])
# epoch 85, loss: 0.995770 |	w tensor([[ 1.9758, -3.3616]]) |	b tensor([4.1815])
# epoch 90, loss: 0.995772 |	w tensor([[ 1.9745, -3.3616]]) |	b tensor([4.1818])
# epoch 95, loss: 0.995771 |	w tensor([[ 1.9750, -3.3608]]) |	b tensor([4.1812])
# epoch 100, loss: 0.995771 |	w tensor([[ 1.9750, -3.3613]]) |	b tensor([4.1815])

# %%
for epoch in range(1, num_epochs + 1):
    for X, y in data_iter:
        trainer_02.zero_grad()
        l = loss(model_02(X).reshape(-1), y)
        l.backward()
        trainer_02.step()
    l = loss(model_02(features).reshape(-1), labels)
    if epoch % 5 == 0:
        print('epoch %d, loss: %f' % (epoch, l.item()),
              '|\tw', model_02.weight.data,
              '|\tb', model_02.bias.data)
# Out:
# epoch 5, loss: 6.231633 |	w tensor([[ 1.2635, -2.0707]]) |	b tensor([2.4895])
# epoch 10, loss: 1.647451 |	w tensor([[ 1.7165, -2.9088]]) |	b tensor([3.5856])
# epoch 15, loss: 1.076682 |	w tensor([[ 1.8821, -3.2029]]) |	b tensor([3.9716])
# epoch 20, loss: 1.005835 |	w tensor([[ 1.9414, -3.3064]]) |	b tensor([4.1071])
# epoch 25, loss: 0.997034 |	w tensor([[ 1.9624, -3.3426]]) |	b tensor([4.1550])
# epoch 30, loss: 0.995926 |	w tensor([[ 1.9710, -3.3554]]) |	b tensor([4.1715])
# epoch 35, loss: 0.995794 |	w tensor([[ 1.9743, -3.3595]]) |	b tensor([4.1768])
# epoch 40, loss: 0.995775 |	w tensor([[ 1.9758, -3.3600]]) |	b tensor([4.1798])
# epoch 45, loss: 0.995771 |	w tensor([[ 1.9764, -3.3613]]) |	b tensor([4.1804])
# epoch 50, loss: 0.995770 |	w tensor([[ 1.9755, -3.3612]]) |	b tensor([4.1804])
# epoch 55, loss: 0.995770 |	w tensor([[ 1.9756, -3.3620]]) |	b tensor([4.1811])
# epoch 60, loss: 0.995771 |	w tensor([[ 1.9752, -3.3628]]) |	b tensor([4.1808])
# epoch 65, loss: 0.995770 |	w tensor([[ 1.9763, -3.3616]]) |	b tensor([4.1811])
# epoch 70, loss: 0.995770 |	w tensor([[ 1.9752, -3.3620]]) |	b tensor([4.1810])
# epoch 75, loss: 0.995770 |	w tensor([[ 1.9755, -3.3622]]) |	b tensor([4.1812])
# epoch 80, loss: 0.995771 |	w tensor([[ 1.9748, -3.3619]]) |	b tensor([4.1807])
# epoch 85, loss: 0.995770 |	w tensor([[ 1.9752, -3.3618]]) |	b tensor([4.1812])
# epoch 90, loss: 0.995771 |	w tensor([[ 1.9749, -3.3619]]) |	b tensor([4.1806])
# epoch 95, loss: 0.995771 |	w tensor([[ 1.9754, -3.3612]]) |	b tensor([4.1821])
# epoch 100, loss: 0.995770 |	w tensor([[ 1.9756, -3.3611]]) |	b tensor([4.1810])
