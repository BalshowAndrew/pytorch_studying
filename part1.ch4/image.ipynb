# %% [markdown]
# ## 4.1 Работа с изображениями

# %%
import imageio
import torch
import os

# %% [markdown]
# ### 4.1.1 Загрузка файла изображения

# %%
img_arr = imageio.v2.imread('../dlwpt-code/data/p1ch4/image-dog/bobby.jpg')
img_arr.shape
# Out:
# (720, 1280, 3)

# %% [markdown]
# ### 4.1.3 Изменение схемы расположения

# %%
img = torch.from_numpy(img_arr)
img.shape
# Out:
# torch.Size([720, 1280, 3])

# %%
out = img.permute(2, 0, 1)
out.shape
# Out:
# torch.Size([3, 720, 1280])

# %%
batch_size = 3
batch = torch.zeros(batch_size, 3, 256, 256, dtype=torch.uint8)

# %%
batch.shape
# Out:
# torch.Size([3, 3, 256, 256])

# %%
data_dir = '../dlwpt-code/data/p1ch4/image-cats'

# %%
os.listdir(data_dir)
# Out:
# ['cat1.png', 'cat2.png', 'cat3.png']

# %%
os.path.splitext(os.listdir(data_dir)[0])[-1]
# Out:
# '.png'

# %%
filenames = [name for name in os.listdir(data_dir)
             if os.path.splitext(name)[-1] == '.png']
filenames
# Out:
# ['cat1.png', 'cat2.png', 'cat3.png']

# %%
for i, filename in enumerate(filenames):
    img_arr = imageio.v2.imread(os.path.join(data_dir, filename))
    print(img_arr.shape)
    img_t = torch.from_numpy(img_arr)
    img_t = img_t.permute(2, 0, 1)
    img_t = img_t[:3]
    batch[i] = img_t
    print(batch[i].shape)
# Out:
# (256, 256, 3)
# torch.Size([3, 256, 256])
# (256, 256, 3)
# torch.Size([3, 256, 256])
# (256, 256, 3)
# torch.Size([3, 256, 256])

# %% [markdown]
# ## 4.2 Трехмерные изображения

# %% [markdown]
# ### 4.2.1 Загрузка данных в специализированном формате

# %%
dir_path = "../dlwpt-code/data/p1ch4/volumetric-dicom/2-LUNG 3.0 B70f-04083"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# Reading DICOM (examining files): 1/99 files (1.0%)
# 43/99 files (43.4%77/99 files (77.8%99/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 33/99  (33.352/99  (52.564/99  (64.675/99  (75.884/99  (84.896/99  (97.099/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol, 0)
vol.shape
# Out:
# torch.Size([1, 99, 512, 512])
